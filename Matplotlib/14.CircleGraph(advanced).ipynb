# %% [markdown]
# # 14. 원 그래프(심화)

# %%
import matplotlib.pyplot as plt
import matplotlib
            
#matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.family'] = 'AppleGothic' # macOS
matplotlib.rcParams['font.size'] = 15 # 글자 크기 변경
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자 깨지는 현상 해결

# %%
values = [30, 25, 20, 13, 10, 2]
labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
colors=['#ffadad', '#ffd6a5', '#fdffb6', '#caffbf', '#9bf6ff', '#a0c4ff']
exploade = [0.05] * 6

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, explode=exploade)
plt.show()

# %%
wedgeprops = {'width':0.6}

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, explode=exploade, wedgeprops=wedgeprops)
plt.show()

# %%
wedgeprops = {'width':0.6, 'edgecolor':'w', 'linewidth':2}

plt.pie(values, labels=labels, autopct='%.1f%%', startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops)
plt.show()

# %%
def custom_autopct(pct):
    #return ('%.1f%%' % pct) if pct >= 10 else ''
    #return '{: .1f%}'.format(pct) if pct >= 10 else ''
    return '{: .0f}%'.format(pct) if pct >= 10 else ''
plt.pie(values, labels=labels, autopct=custom_autopct, startangle=90, counterclock=False, colors = colors, wedgeprops=wedgeprops, pctdistance=0.7)
plt.show()

# %% [markdown]
# ## DataFrame 활용

# %%
import pandas as pd

df = pd.read_excel('../Pandas/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키 포지션   득점  리바운드  어시스트  스틸  블록
# 0   1번  채치수  북산고  197  PF   70    11    10   2   1
# 1   2번  정대만  북산고  184   C   45    10     7   9  13
# 2   3번  송태섭  북산고  168  PG   37     5     7   4   4
# 3   4번  서태웅  북산고  187  SG  101     9     6   3   1
# 4   5번  강백호  북산고  188  SF   49     0    17  12   4
# 5   6번  변덕규  능남고  202  PF   72    19     8   1  19
# 6   7번  황태산  능남고  188   C   68    26    14   2  15
# 7   8번  윤대협  능남고  190  PG   12     5    10   2   3

# %%
grp = df.groupby('학교')
grp

# %%
grp.size()['능남고']
# Out:
# np.int64(3)

# %%
values = [grp.size()['북산고'], grp.size()['능남고']]# [5, 3]
labels = ['북산고', '능남고']
wedgeprops = {'width':0.5}


plt.pie(values, labels=labels, autopct='%.0f%%', wedgeprops=wedgeprops, pctdistance=0.7)
plt.title('소속 학교')
plt.legend(loc=(1.0, 0.4), title='소속 학교 선호도')
plt.show()
