# %% [markdown]
# # 16. 여러 그래프

# %%
import matplotlib.pyplot as plt
import matplotlib
            
#matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.family'] = 'AppleGothic' # macOS
matplotlib.rcParams['font.size'] = 15 # 글자 크기 변경
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자 깨지는 현상 해결

# %%
import pandas as pd

df = pd.read_excel('../Pandas/score.xlsx')
df
# Out:
#   지원번호   이름   학교    키 포지션   득점  리바운드  어시스트  스틸  블록
# 0   1번  채치수  북산고  197  PF   70    11    10   2   1
# 1   2번  정대만  북산고  184   C   45    10     7   9  13
# 2   3번  송태섭  북산고  168  PG   37     5     7   4   4
# 3   4번  서태웅  북산고  187  SG  101     9     6   3   1
# 4   5번  강백호  북산고  188  SF   49     0    17  12   4
# 5   6번  변덕규  능남고  202  PF   72    19     8   1  19
# 6   7번  황태산  능남고  188   C   68    26    14   2  15
# 7   8번  윤대협  능남고  190  PG   12     5    10   2   3

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 15)) # 2 X 2에 해당하는 plot 들을 생성
fig.suptitle('여러개의 그래프 만들기')

# 첫 번째 그래프
axs[0,0].bar(df['이름'], df['득점'], label='득점') # 데이터 설정
axs[0,0].set_title('첫 번째 득점 수 그래프') # 제목
axs[0,0].legend() # 범례
axs[0,0].set(xlabel='이름', ylabel='득점 점수') # x, y축 label
axs[0,0].set_facecolor('lightyellow') # 전면 색
axs[0,0].grid(linestyle='--', linewidth=0.5)

# 두 번째 그래프
axs[0,1].plot(df['이름'], df['블록'], label='블록')
axs[0,1].set_title('두 번째 블록,리바운드 그래프') 
axs[0,1].plot(df['이름'], df['리바운드'], label='리바운드')
axs[0,1].legend()

# 세 번째 그래프
axs[1, 0].barh(df['이름'], df['키'])
axs[1,0].set_title('세 번째 학생별 키 그래프') 

# 네 번째 그래프
axs[1, 1].scatter(df['이름'], df['스틸'], color = 'green', alpha = 0.5)
axs[1,1].set_title('네 번째 학생별 스틸 그래프')
# Out:
# Text(0.5, 1.0, '네 번째 학생별 스틸 그래프')
